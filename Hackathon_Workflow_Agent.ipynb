# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhavik-Pahwa/Bhavik-Pahwa/blob/main/Hackathon_Workflow_Agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Plan
# > An Agent that helps me setup the initial workflow of any hackathon that i participate in.
